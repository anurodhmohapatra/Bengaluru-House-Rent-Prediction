# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading CSV File

# %%
df1 = pd.read_csv('House_Data_Bangalore_for_EDA.csv')

# %%
df1.head()
# Out:
#    BHK                   Address  Latitude  Longitude  Size(Acres)  \
# 0    2          Kadubeesanahalli    12.934     77.702         1210
# 1    2       Sivanchetti Gardens    12.983     77.612          750
# 2    1   Aecs Layout Singasandra    12.883     77.650          500
# 3    3                 Bellandur    12.924     77.685         1879
# 4    3                  Rr Nagar    12.919     77.501         1620
#
#    Deposit(Rs)  Rent(Rs)      Furnishing       Property Age Available For  \
# 0       150000     21000  Semi Furnished         3-5 years         Family
# 1       200000     22000  Semi Furnished         3-5 years            All
# 2        50000     10000  Semi Furnished  Newly Constructed        Family
# 3       250000     43000  Semi Furnished        5-10 years            All
# 4       100000     20000  Semi Furnished         3-5 years         Family
#
#    Immediate Possesion                                               Link
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9632 entries, 0 to 9631
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   BHK                   9632 non-null   int64
#  1   Address               9632 non-null   object
#  2   Latitude              9632 non-null   float64
#  3   Longitude             9632 non-null   float64
#  4   Size(Acres)           9632 non-null   int64
#  5   Deposit(Rs)           9632 non-null   int64
#  6   Rent(Rs)              9632 non-null   int64
#  7   Furnishing            9632 non-null   object
#  8   Property Age          9632 non-null   object
#  9   Available For         9632 non-null   object
#  10   Immediate Possesion  9632 non-null   object
#  11  Link                  9632 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 903.1+ KB

# %% [markdown]
# # Univariate Analysis

# %%
df1.columns
# Out:
# Index(['BHK', 'Address', 'Latitude', 'Longitude', 'Size(Acres)', 'Deposit(Rs)',
#        'Rent(Rs)', 'Furnishing', 'Property Age', 'Available For',
#        ' Immediate Possesion', 'Link'],
#       dtype='object')

# %% [markdown]
# ## Address

# %%
len(df1['Address'].unique())
# Out:
# 1419

# %% [markdown]
# **Since Address column have 1419 unique values. I will keep only those rows whose value count is more than 10.**

# %%
address=[]
for key,value in df1['Address'].value_counts().iteritems():
    if value>=20:
        address.append(key)

# %%
len(address)
# Out:
# 100

# %%
df2 = df1[df1['Address'].isin(address)]

# %%
plt.figure(figsize=(10,20))
sns.countplot(y=df2['Address'],order=df2['Address'].value_counts().index)
plt.show()

# %% [markdown]
# **I noticed there is a blank address, Two Indira Nagar one with space and other withhout and some address named as India. I will replace them with others.**

# %%
empty_rows = df2[(df2['Address']==' ') | (df2['Address']==' India')].index
df3 = df2.copy()
for row in empty_rows:
    df3.loc[row,'Address']='others'
    
df3['Address'] = df3['Address'].str.replace('Indira Nagar','Indiranagar')

# %% [markdown]
# ## Furnishing

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df3['Furnishing'],order=df3['Furnishing'].value_counts().index)
plt.show()

# %% [markdown]
# **This column is very biased I will remove it later.**

# %% [markdown]
# ## Property Age

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df3['Property Age'],order=df3['Property Age'].value_counts().index)
plt.show()

# %% [markdown]
# ## Available For

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df3['Available For'],order=df3['Available For'].value_counts().index)
plt.show()

# %% [markdown]
# **This column is also biased. I may remove it.**

# %% [markdown]
# ## Size(Acres)

# %%
plt.figure(figsize=(25,7))
sns.histplot(df3['Size(Acres)'])
plt.show()

# %% [markdown]
# **It is right skewed. And some values are zero.**

# %%
df3[df3['Size(Acres)']==0]
# Out:
#       BHK          Address  Latitude  Longitude  Size(Acres)  Deposit(Rs)  \
# 7988    2   Murgesh Pallya    12.954     77.653            0        75000
# 9094    2    Kasavanahalli    12.898     77.678            0       175000
#
#       Rent(Rs)   Furnishing Property Age Available For  Immediate Possesion  \
# 7988     16000  UnFurnished   1-3 years            All        Ready to Move
# 9094     15000  UnFurnished   >10 years         Family        Ready to Move
#
#                                                    Link
# 7988  https://www.nobroker.in/property/2-bhk-apartme...
# 9094  https://www.nobroker.in/property/2-bhk-apartme...

# %%
df4 = df3[df3['Size(Acres)']!=0]

# %% [markdown]
# **After log transformation**

# %%
plt.figure(figsize=(25,7))
sns.histplot(np.log(df4['Size(Acres)']))
plt.show()

# %% [markdown]
# ## Rent(Rs)

# %%
plt.figure(figsize=(25,7))
sns.histplot(df4['Rent(Rs)'])
plt.show()

# %% [markdown]
# **It is right skewed.**

# %%
plt.figure(figsize=(25,7))
sns.histplot(np.log(df4['Rent(Rs)']))
plt.show()

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# ## Address vs Rent

# %%
plt.figure(figsize=(10,20))
sns.barplot(y=df4['Address'],x=df4['Rent(Rs)'],
            order=df4.groupby(by='Address').mean()['Rent(Rs)'].sort_values(ascending=False).index)
plt.show()

# %% [markdown]
# ## Property Age vs Rent

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=df4['Property Age'],y=df4['Rent(Rs)'],
            order=df4.groupby(by='Property Age').mean()['Rent(Rs)'].sort_values(ascending=False).index)
plt.show()

# %% [markdown]
# **Since all values are almost same. Property Age wil not play important factor on predicting**

# %% [markdown]
# ## Size vs Rent

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x=df4['Size(Acres)'],y=df4['Rent(Rs)'])
plt.show()

# %% [markdown]
# ## Outlier Treatment
#
# **Since data is not in Gaussian distribution form. I will use iqr method to remove outliers**

# %%
# calculate interquartile range
q25, q75 = np.percentile(df4['Rent(Rs)'], 25), np.percentile(df4['Rent(Rs)'], 75)
iqr = q75 - q25
print('Percentiles: 25th=%.3f, 75th=%.3f, IQR=%.3f' % (q25, q75, iqr))
# calculate the outlier cutoff
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off
# identify outliers
outliers = [x for x in df4['Rent(Rs)'] if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
# remove outliers
outliers_removed = [x for x in df4['Rent(Rs)'] if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Percentiles: 25th=12000.000, 75th=25000.000, IQR=13000.000
# Identified outliers: 175
# Non-outlier observations: 6029

# %%
df5 = df4[~df4['Rent(Rs)'].isin(outliers)]

# %%
# calculate interquartile range
q25, q75 = np.percentile(df5['Size(Acres)'], 25), np.percentile(df5['Size(Acres)'], 75)
iqr = q75 - q25
print('Percentiles: 25th=%.3f, 75th=%.3f, IQR=%.3f' % (q25, q75, iqr))
# calculate the outlier cutoff
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off
# identify outliers
outliers = [x for x in df5['Size(Acres)'] if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
# remove outliers
outliers_removed = [x for x in df5['Size(Acres)'] if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Percentiles: 25th=700.000, 75th=1303.000, IQR=603.000
# Identified outliers: 51
# Non-outlier observations: 5978

# %%
df6 = df5[~df5['Size(Acres)'].isin(outliers)]

# %%
plt.figure(figsize=(15,7))
sns.regplot(x=df6['Size(Acres)'],y=df6['Rent(Rs)'])
plt.show()

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df6.corr(),annot=True)
plt.show()

# %% [markdown]
# **Since BHK and Size are correlated there is no use of using both column**

# %% [markdown]
# ### Currently I will export this data to CSV for model creation and Later I will plot more charts such as a map which shows Rent area vice, etc.

# %%
df6.loc[:,'Address'] = df6.loc[:,'Address'].str.strip()

# %%
df6.to_csv('House_Data_Bangalore_for_Model.csv',index=False)
